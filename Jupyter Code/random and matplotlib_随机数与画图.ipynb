# %%
import numpy as np

# %%
a=2*np.random.rand(10,2)+3
x=np.random.rand(2,3)
y=np.random.rand(3,2)
z=np.dot(x,y)
np.random.normal(3.0,2.0,(4,5))
# Out:
# array([[1.16941956, 1.59850927, 6.5973849 , 0.03557231, 3.90198155],
#        [4.82867001, 1.31108518, 0.12937134, 2.36326181, 3.30480518],
#        [2.32730059, 2.12089615, 3.82871628, 1.55984589, 5.54510418],
#        [3.77835447, 0.38770416, 5.34212688, 1.76830865, 6.21748335]])

# %%
import matplotlib.pyplot as plt

# %%
p = plt.figure()
p1 = p.add_subplot(3,1,1)
p2 = p.add_subplot(3,1,2)
p3 = p.add_subplot(3,1,3)
##add_pubplot（3，1，2）的意思是所有图标有三行一列，当前的在第二个
p1.plot(np.random.rand(10),'k--')
p2.hist(np.random.rand(100),bins=10)
p3.scatter(a[:,0],a[:,1])

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot((np.random.rand(1000)-0.5).cumsum())

# %%
w=np.random.normal(4,3,2)
x=np.arange(10)
y=w[0]*x+w[1]
#取两组随机数
d1=np.array([np.random.normal(3,0.5,800),np.random.normal(4,0.5,800)]).T
d2=np.array([np.random.normal(2,0.5,800),np.random.normal(8,0.5,800)]).T
dd=np.vstack((d1,d2))
#打乱顺序
np.random.shuffle(dd)
d=dd[:500]
plt.plot(d[:,0],d[:,1],'.','b')

# %%
x = np.linspace(0 , 10)
plt.plot(x,x, label='x1')
plt.plot(x,x**2, label='x2')
plt.plot(x,x**3, label='x3')
plt.ylabel('y_label')
plt.xlabel('x_label')
plt.title('Drawing')
plt.legend()
plt.show()

# %%
x = np.linspace(0,9)
fig = plt.figure(figsize=(16.4, 14.8))
fig, ax = plt.subplots()
ax.plot(x,np.sin(x))
plt.show()
